-- %% [markdown]
-- # [AgenciaDeViaje]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [AgenciaDeViaje]    Script Date: 12/3/2023 5:05:39 PM ******/
CREATE DATABASE [AgenciaDeViaje]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'AgenciaDeViaje', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\AgenciaDeViaje.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'AgenciaDeViaje_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\AgenciaDeViaje_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [AgenciaDeViaje] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [AgenciaDeViaje].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [AgenciaDeViaje] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [AgenciaDeViaje] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [AgenciaDeViaje] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [AgenciaDeViaje] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [AgenciaDeViaje] SET ARITHABORT OFF 
GO
ALTER DATABASE [AgenciaDeViaje] SET AUTO_CLOSE ON 
GO
ALTER DATABASE [AgenciaDeViaje] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [AgenciaDeViaje] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [AgenciaDeViaje] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [AgenciaDeViaje] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [AgenciaDeViaje] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [AgenciaDeViaje] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [AgenciaDeViaje] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [AgenciaDeViaje] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [AgenciaDeViaje] SET  ENABLE_BROKER 
GO
ALTER DATABASE [AgenciaDeViaje] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [AgenciaDeViaje] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [AgenciaDeViaje] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [AgenciaDeViaje] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [AgenciaDeViaje] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [AgenciaDeViaje] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [AgenciaDeViaje] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [AgenciaDeViaje] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [AgenciaDeViaje] SET  MULTI_USER 
GO
ALTER DATABASE [AgenciaDeViaje] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [AgenciaDeViaje] SET DB_CHAINING OFF 
GO
ALTER DATABASE [AgenciaDeViaje] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [AgenciaDeViaje] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [AgenciaDeViaje] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [AgenciaDeViaje] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [AgenciaDeViaje] SET QUERY_STORE = ON
GO
ALTER DATABASE [AgenciaDeViaje] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Actividades]

-- %%
USE [AgenciaDeViaje]
GO

-- %%
/****** Object:  Table [dbo].[Actividades]    Script Date: 12/3/2023 5:05:39 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Actividades](
	[ActividadID] [int] IDENTITY(1,1) NOT NULL,
	[DestinoID] [int] NULL,
	[Nombre] [nvarchar](100) NOT NULL,
	[TipoActividad] [nvarchar](100) NOT NULL,
	[Dias] [int] NOT NULL,
	[Precio] [decimal](10, 2) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[ActividadID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Destinos]

-- %%
/****** Object:  Table [dbo].[Destinos]    Script Date: 12/3/2023 5:05:39 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Destinos](
	[DestinoID] [int] IDENTITY(1,1) NOT NULL,
	[Nombre] [nvarchar](100) NOT NULL,
	[ImagenURL] [nvarchar](50) NOT NULL,
	[Pais] [nvarchar](50) NOT NULL,
	[Requisitos] [nvarchar](50) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[DestinoID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DestinosBuscados]

-- %%
/****** Object:  Table [dbo].[DestinosBuscados]    Script Date: 12/3/2023 5:05:39 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DestinosBuscados](
	[DestinoBuscadoID] [int] IDENTITY(1,1) NOT NULL,
	[UsuarioID] [int] NULL,
	[DestinoID] [int] NULL,
	[FechaBusqueda] [datetime] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[DestinoBuscadoID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Reservas]

-- %%
/****** Object:  Table [dbo].[Reservas]    Script Date: 12/3/2023 5:05:39 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Reservas](
	[ReservaID] [int] IDENTITY(1,1) NOT NULL,
	[UsuarioID] [int] NULL,
	[DestinoID] [int] NULL,
	[FechaReserva] [datetime] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[ReservaID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Usuarios]

-- %%
/****** Object:  Table [dbo].[Usuarios]    Script Date: 12/3/2023 5:05:39 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Usuarios](
	[UsuarioID] [int] IDENTITY(1,1) NOT NULL,
	[NombreUsuario] [nvarchar](50) NOT NULL,
	[Contraseña] [varchar](50) NOT NULL,
	[TipoUsuario] [varchar](20) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[UsuarioID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK__Actividad__Desti__4D94879B]

-- %%
ALTER TABLE [dbo].[Actividades]  WITH CHECK ADD FOREIGN KEY([DestinoID])
REFERENCES [dbo].[Destinos] ([DestinoID])
GO

-- %% [markdown]
-- # [FK__DestinosB__Desti__5535A963]

-- %%
ALTER TABLE [dbo].[DestinosBuscados]  WITH CHECK ADD FOREIGN KEY([DestinoID])
REFERENCES [dbo].[Destinos] ([DestinoID])
GO

-- %% [markdown]
-- # [FK__DestinosB__Usuar__5441852A]

-- %%
ALTER TABLE [dbo].[DestinosBuscados]  WITH CHECK ADD FOREIGN KEY([UsuarioID])
REFERENCES [dbo].[Usuarios] ([UsuarioID])
GO

-- %% [markdown]
-- # [FK__Reservas__Destin__5165187F]

-- %%
ALTER TABLE [dbo].[Reservas]  WITH CHECK ADD FOREIGN KEY([DestinoID])
REFERENCES [dbo].[Destinos] ([DestinoID])
GO

-- %% [markdown]
-- # [FK__Reservas__Usuari__5070F446]

-- %%
ALTER TABLE [dbo].[Reservas]  WITH CHECK ADD FOREIGN KEY([UsuarioID])
REFERENCES [dbo].[Usuarios] ([UsuarioID])
GO

-- %% [markdown]
-- # [AgenciaDeViaje]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [AgenciaDeViaje] SET  READ_WRITE 
GO
